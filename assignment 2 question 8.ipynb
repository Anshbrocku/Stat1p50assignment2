# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('students2.csv')

data2 = data[['Programming skill','Theoretical knowledge', 'Class']]
length=len(data)
data3=[]
data4=[]
data5=[]
data6=[]
for i in range(0,length):
    if data.loc[i,'Class']<3:
     data3=data3+[data.loc[i,'Programming skill']]
     data4=data4+[data.loc[i,'Theoretical knowledge']]
    else:
        data5=data5+[data.loc[i,'Programming skill']]
        data6=data6+[data.loc[i,'Theoretical knowledge']]
        
        
   

plt.boxplot(data3)
plt.show()
plt.boxplot(data4)
plt.show()
plt.boxplot(data5)
plt.show()
plt.boxplot(data6)
plt.show()
